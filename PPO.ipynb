# %%
import gymnasium as gym
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt

from tqdm import tqdm
import torch.nn as nn
from itertools import count

from multigrid.envs.empty import EmptyEnv

import torch as T
from torch import optim
import torch.nn.functional as F
from collections import deque , namedtuple
from itertools import count
# set up matplotlib
from IPython import display

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

import minigrid
from minigrid.wrappers import ImgObsWrapper
from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

plt.ion()
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")




class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512, normalized_image: bool = False) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))



if __name__ == "__main__":
    
    # env = gym.make(
    #     "LunarLander-v2",
    #     continuous = False,
    #     gravity = -10.0,
    #     enable_wind = False,
    #     wind_power = 15.0,
    #     turbulence_power = 1.5
    # )

    policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
    )

    env = gym.make("MiniGrid-Empty-16x16-v0", render_mode="rgb_array")
    env = ImgObsWrapper(env)
    

    model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
    model.learn(2e5)


    print("we did it")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015026742 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -2.89       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0096     |
# |    value_loss           | 3.05e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024481148 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -1.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00947    |
# |    value_loss           | 7.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017579168 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -6.35       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0913      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 8.37e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 5            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0139250755 |
# |    clip_fraction        | 0.099        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | -9.07        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0597      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00941     |
# |    value_loss           | 1.41e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012803515 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -6.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 2.19e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020718876 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -4.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0441     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 3.61e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | 0.123       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 8           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013230918 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -1.52       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 6.92e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | 0.148       |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.020584956 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.0879     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.00505     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 0.275       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 10          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016470687 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.0802      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000728   |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 591         |
# |    ep_rew_mean          | 0.439       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 11          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014238661 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.0963      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 0.0126      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 463         |
# |    ep_rew_mean          | 0.562       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 12          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018228468 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0058      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.0228      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 364         |
# |    ep_rew_mean          | 0.658       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 13          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008809742 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 0.0269      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 295        |
# |    ep_rew_mean          | 0.724      |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 14         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01167194 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0328     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 0.0195     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 0.904       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 15          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012396285 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00482     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.0209      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.4        |
# |    ep_rew_mean          | 0.938       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 16          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014778752 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.1        |
# |    ep_rew_mean          | 0.95        |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 17          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015755493 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00378    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.017       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | 0.958       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 18          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010188576 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | 0.962       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 19          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008582812 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0248     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.00784     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | 0.966       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 20          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008486722 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0274     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00835    |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.2        |
# |    ep_rew_mean          | 0.968       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 21          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006663643 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00779     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 0.00479     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.3        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 22          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009397872 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 0.00348     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.8        |
# |    ep_rew_mean          | 0.971       |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 23          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006502618 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00583    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.6       |
# |    ep_rew_mean          | 0.955      |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 24         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.17144811 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.511     |
# |    explained_variance   | 0.626      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0251     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00595   |
# |    value_loss           | 0.00334    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.8        |
# |    ep_rew_mean          | 0.938       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 25          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010114307 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | -2.69       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00621    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00348     |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90         |
# |    ep_rew_mean          | 0.919      |
# | time/                   |            |
# |    fps                  | 396        |
# |    iterations           | 26         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01985014 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.817     |
# |    explained_variance   | -0.654     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00947   |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.00261    |
# |    value_loss           | 0.00147    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 108        |
# |    ep_rew_mean          | 0.903      |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 27         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.04974396 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.933     |
# |    explained_variance   | -0.298     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0089    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0151     |
# |    value_loss           | 0.000914   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 0.891       |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 28          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.018496739 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.0323      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00179     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.000188    |
# |    value_loss           | 0.00648     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 0.881       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 29          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010898044 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000126    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0067     |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | 0.897       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 30          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.021440253 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0195      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.0177      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 58.5      |
# |    ep_rew_mean          | 0.949     |
# | time/                   |           |
# |    fps                  | 390       |
# |    iterations           | 31        |
# |    time_elapsed         | 162       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0072993 |
# |    clip_fraction        | 0.0792    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.675    |
# |    explained_variance   | 0.322     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00517   |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.0107   |
# |    value_loss           | 0.0139    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.5        |
# |    ep_rew_mean          | 0.961       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 32          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018525949 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0173      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | 0.969       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 33          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012705483 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00516    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00711     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33           |
# |    ep_rew_mean          | 0.971        |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 34           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0062693716 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00364      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.00515      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.2        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 35          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011159942 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 0.00392     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 36          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017854827 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00962    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 0.00303     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.9         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 37           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0049470663 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00734      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.00264      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.8         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 38           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0014310144 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000443     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.7         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 39           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0013095434 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00171      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000844    |
# |    value_loss           | 0.00211      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 40          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013079591 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00108    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000908    |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 41          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028534828 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00273    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 42          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008591134 |
# |    clip_fraction        | 0.00854     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00908     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.4          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 43            |
# |    time_elapsed         | 229           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00067828945 |
# |    clip_fraction        | 0.0085        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0708       |
# |    explained_variance   | 0.634         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00112       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 0.00204       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.4         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 44           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0002961019 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0593      |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00119      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000805    |
# |    value_loss           | 0.00203      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.3          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 45            |
# |    time_elapsed         | 240           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00027972693 |
# |    clip_fraction        | 0.00542       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0629       |
# |    explained_variance   | 0.643         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00101       |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000523     |
# |    value_loss           | 0.00218       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.3         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 46           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0005089202 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0563      |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000174     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000755    |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 47            |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00033351104 |
# |    clip_fraction        | 0.0042        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0453       |
# |    explained_variance   | 0.645         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00048       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000268     |
# |    value_loss           | 0.00209       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 48            |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00025915029 |
# |    clip_fraction        | 0.00337       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0496       |
# |    explained_variance   | 0.629         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000951      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000644     |
# |    value_loss           | 0.00192       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 49            |
# |    time_elapsed         | 260           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00026951055 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0517       |
# |    explained_variance   | 0.642         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000895      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | 0.000157      |
# |    value_loss           | 0.00182       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 50            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00028168465 |
# |    clip_fraction        | 0.00386       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0573       |
# |    explained_variance   | 0.636         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000783      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000601     |
# |    value_loss           | 0.00193       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 51            |
# |    time_elapsed         | 269           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00023890848 |
# |    clip_fraction        | 0.00303       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0524       |
# |    explained_variance   | 0.622         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000776      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -6.42e-06     |
# |    value_loss           | 0.00191       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 388           |
# |    iterations           | 52            |
# |    time_elapsed         | 274           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00025552613 |
# |    clip_fraction        | 0.00298       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0487       |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000933      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000463     |
# |    value_loss           | 0.0019        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 388           |
# |    iterations           | 53            |
# |    time_elapsed         | 279           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00021026851 |
# |    clip_fraction        | 0.00449       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0438       |
# |    explained_variance   | 0.643         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000831      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000708     |
# |    value_loss           | 0.00192       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 389           |
# |    iterations           | 54            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00024221619 |
# |    clip_fraction        | 0.00371       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0397       |
# |    explained_variance   | 0.645         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000745      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000627     |
# |    value_loss           | 0.00201       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 55            |
# ...
# |    ep_rew_mean          | 0.972       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 81          |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.013835314 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00126     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00327     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.6        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 82          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.030989634 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00337     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 83          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.023765322 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00572    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 84          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004503811 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.122      |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00491    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 85          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.008264676 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0951     |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00199    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.6         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 86           |
# |    time_elapsed         | 453          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0014564946 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0818      |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0011       |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.6        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 87          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.017575894 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0684     |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000221    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 88          |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.026902966 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0482     |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00015    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.2         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 89           |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 8.096796e-05 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.052       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00606      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 1.34e-05     |
# |    value_loss           | 0.00197      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.2         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 90           |
# |    time_elapsed         | 475          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0002924817 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.044       |
# |    explained_variance   | 0.642        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0086      |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.000649    |
# |    value_loss           | 0.00199      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 91            |
# |    time_elapsed         | 481           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00012921766 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.046        |
# |    explained_variance   | 0.641         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000677      |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -0.000132     |
# |    value_loss           | 0.00201       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 92            |
# |    time_elapsed         | 486           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 8.4407075e-05 |
# |    clip_fraction        | 0.00181       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0393       |
# |    explained_variance   | 0.642         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00102       |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -0.000193     |
# |    value_loss           | 0.00198       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 93            |
# |    time_elapsed         | 492           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 0.00043397877 |
# |    clip_fraction        | 0.004         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0431       |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000786      |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -0.000899     |
# |    value_loss           | 0.00192       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 94            |
# |    time_elapsed         | 498           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00013729089 |
# |    clip_fraction        | 0.00161       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.042        |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00235      |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -0.000311     |
# |    value_loss           | 0.0019        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 95          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.006809669 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0468     |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00241     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.000654   |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.1        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 96          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.009259292 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e-05     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 97          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.024919702 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0927     |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 98          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.012439517 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0468     |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000989    |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# we did it

# %%
from multigrid.envs.empty import EmptyEnv

env = EmptyEnv(size=8)

# agent = Agent(env)
# agent.train(20,env)
# print("we did it")

# %%
state, info = env.reset()

# %%
state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
#
# TypeError: must be real number, not dict

# %%
state[0]["image"].size
# Out:
# 147
